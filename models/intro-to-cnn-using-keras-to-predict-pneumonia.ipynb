# %% [markdown]
# # <font color='purple'>The purpose of this exercise is to see how accurate of a Neural Network we can create to classify X-Ray scans from patients with pneumonia. </font>
#
# ![https://media.giphy.com/media/l0MYtoPNAQ0YCgNVe/giphy.gif](https://media.giphy.com/media/l0MYtoPNAQ0YCgNVe/giphy.gif)

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 2.4.0
# asttokens               3.0.1
# astunparse              1.6.3
# certifi                 2026.4.22
# charset-normalizer      3.4.7
# comm                    0.2.3
# debugpy                 1.8.20
# decorator               5.2.1
# executing               2.2.1
# flatbuffers             25.12.19
# gast                    0.7.0
# google-pasta            0.2.0
# grpcio                  1.80.0
# h5py                    3.14.0
# idna                    3.13
# ipykernel               7.2.0
# ipython                 9.13.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# keras                   3.14.0
# libclang                18.1.1
# markdown-it-py          4.0.0
# matplotlib-inline       0.2.1
# mdurl                   0.1.2
# ml_dtypes               0.5.4
# namex                   0.1.0
# nest-asyncio            1.6.0
# numpy                   2.4.4
# opt_einsum              3.4.0
# optree                  0.19.0
# packaging               26.2
# parso                   0.8.6
# pexpect                 4.9.0
# pip                     26.1
# platformdirs            4.9.6
# prompt_toolkit          3.0.52
# protobuf                7.34.1
# psutil                  7.2.2
# ptyprocess              0.7.0
# pure_eval               0.2.3
# Pygments                2.20.0
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# requests                2.33.1
# rich                    15.0.0
# setuptools              82.0.1
# six                     1.17.0
# stack-data              0.6.3
# tensorflow              2.21.0
# termcolor               3.3.0
# tornado                 6.5.5
# traitlets               5.14.3
# typing_extensions       4.15.0
# urllib3                 2.6.3
# wcwidth                 0.6.0
# wheel                   0.47.0
# wrapt                   2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install keras
# %pip install tensorflow
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install scikit-learn
# %pip install pillow
# %pip install keras
# Out:
# Requirement already satisfied: keras in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (3.14.0)
# Requirement already satisfied: absl-py in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (2.4.0)
# Requirement already satisfied: numpy in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (2.4.4)
# Requirement already satisfied: rich in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (26.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (2.4.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (12.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (3.14.0)
# Requirement already satisfied: absl-py in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (2.4.0)
# Requirement already satisfied: numpy in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (2.4.4)
# Requirement already satisfied: rich in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras) (26.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd notebooks/CNN/
# Out:
# /home/arthur/Desktop/AI300/House_Rent_proj/House_Rent_Pred/models/notebooks/CNN

# %%
# Install the complete set of CUDA 12 components for TensorFlow 2.21
# %pip install nvidia-cuda-runtime-cu12 nvidia-cudnn-cu12 nvidia-cublas-cu12 \
             nvidia-cufft-cu12 nvidia-curand-cu12 nvidia-cusolver-cu12 \
             nvidia-cusparse-cu12 nvidia-nvcc-cu12 nvidia-nvml-ptr
# Out:
# Requirement already satisfied: nvidia-cuda-runtime-cu12 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (12.9.79)
# Requirement already satisfied: nvidia-cudnn-cu12 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (9.21.1.3)
# Requirement already satisfied: nvidia-cublas-cu12 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (12.9.2.10)
# Collecting nvidia-cufft-cu12
#   Using cached nvidia_cufft_cu12-11.4.1.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-curand-cu12 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (10.3.10.19)
# Collecting nvidia-cusolver-cu12
#   Using cached nvidia_cusolver_cu12-11.7.5.82-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparse-cu12
#   Using cached nvidia_cusparse_cu12-12.5.10.65-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ERROR: Could not find a version that satisfies the requirement nvidia-nvcc-cu12 (from versions: none)
# ERROR: No matching distribution found for nvidia-nvcc-cu12
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow[cuda]
# %pip install tensorflow[and-cuda]
# Out:
# Requirement already satisfied: tensorflow[cuda] in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (2.21.0)
# WARNING: tensorflow 2.21.0 does not provide the extra 'cuda'
# Requirement already satisfied: absl-py>=1.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (2.33.1)
# Requirement already satisfied: setuptools in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[cuda]) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[cuda]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[cuda]) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[cuda]) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[cuda]) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow[cuda]) (0.47.0)
# Requirement already satisfied: rich in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[cuda]) (15.0.0)
# Requirement already satisfied: namex in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[cuda]) (0.1.0)
# Requirement already satisfied: optree in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[cuda]) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[cuda]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow[cuda]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow[and-cuda] in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.33.1)
# Requirement already satisfied: setuptools in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.5.4)
# Requirement already satisfied: nvidia-cublas-cu12<13.0,>=12.5.3.2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.2.10)
# Requirement already satisfied: nvidia-cuda-cupti-cu12<13.0,>=12.5.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.79)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13.0,>=12.5.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.79)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.3.0.75 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (9.21.1.3)
# Requirement already satisfied: nvidia-cufft-cu12<12.0,>=11.2.3.61 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.4.1.4)
# Requirement already satisfied: nvidia-curand-cu12<11.0,>=10.3.6.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (10.3.10.19)
# Requirement already satisfied: nvidia-cusolver-cu12<12.0,>=11.6.3.83 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.7.5.82)
# Requirement already satisfied: nvidia-cusparse-cu12<13.0,>=12.5.1.3 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.5.10.65)
# Requirement already satisfied: nvidia-nccl-cu12<3.0,>=2.27.7 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.30.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12<13.0,>=12.5.82 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.86)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.47.0)
# Requirement already satisfied: rich in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (15.0.0)
# Requirement already satisfied: namex in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (0.1.0)
# Requirement already satisfied: optree in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[and-cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[and-cuda]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow[and-cuda]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # <font color ='purple'>Let's start by Importing the required libraries </font>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777664227.390175   12825 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
# Adjust the path to match your virtual environment location
env_path = "/home/arthur/Desktop/AI300/House_Rent_proj/tf_compatible_env/lib/python3.12/site-packages/nvidia/cudnn/lib"
os.environ['LD_LIBRARY_PATH'] = env_path + ":" + os.environ.get('LD_LIBRARY_PATH', '')

# %%
# !sudo usermod -aG video $USER
# !sudo usermod -aG render $USER
# Out:
# [sudo] password for arthur:
# sudo: a password is required
# ^C

# %%
# Verify GPU availability
print("TensorFlow Version:", tf.__version__)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"✅ GPU Detected: {gpus[0].name}")
    # This prevents TF from hogging all VRAM immediately
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("❌ GPU NOT detected. Check your CUDA/cuDNN installation.")
# Out:
# TensorFlow Version: 2.21.0
# ❌ GPU NOT detected. Check your CUDA/cuDNN installation.

# %%
from tensorflow.keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print('Compute dtype: %s' % policy.compute_dtype)
print('Variable dtype: %s' % policy.variable_dtype)
# Out:
# Compute dtype: float16
# Variable dtype: float32

# %% [markdown]
# ### Input data and preprocessing:

# %%
mainDIR = os.listdir('input/chest_xray/chest_xray')
print(mainDIR)
# Out:
# ['val', 'train', 'test', '.DS_Store']

# %%
train_folder= 'input/chest_xray/chest_xray/train/'
val_folder = 'input/chest_xray/chest_xray/val/'
test_folder = 'input/chest_xray/chest_xray/test/'

# %% [markdown]
# ## Let's set up the training and testing folders.

# %%
# train 
os.listdir(train_folder)
train_n = train_folder+'NORMAL/'
train_p = train_folder+'PNEUMONIA/'

# %% [markdown]
# ## Let's take a look at some of the pictures.

# %%
#Normal pic 
print(len(os.listdir(train_n)))
rand_norm= np.random.randint(0,len(os.listdir(train_n)))
norm_pic = os.listdir(train_n)[rand_norm]
print('normal picture title: ',norm_pic)

norm_pic_address = train_n+norm_pic

#Pneumonia
rand_p = np.random.randint(0,len(os.listdir(train_p)))

sic_pic =  os.listdir(train_p)[rand_norm]
sic_address = train_p+sic_pic
print('pneumonia picture title:', sic_pic)

# Load the images
norm_load = Image.open(norm_pic_address)
sic_load = Image.open(sic_address)

#Let's plt these images
f = plt.figure(figsize= (10,6))
a1 = f.add_subplot(1,2,1)
img_plot = plt.imshow(norm_load)
a1.set_title('Normal')

a2 = f.add_subplot(1, 2, 2)
img_plot = plt.imshow(sic_load)
a2.set_title('Pneumonia')
# Out:
# 1342
# normal picture title:  IM-0624-0001.jpeg
# pneumonia picture title: person1003_bacteria_2934.jpeg
# Text(0.5, 1.0, 'Pneumonia')

# %% [markdown]
# **The above pictures are being generated randomly from the dataset. There are slight differences in the pictures, but  let's see if we can't create a Convolutional Neural Network which can create a more objective measure of quantifying and classifying these differences. **

# %% [markdown]
# # <font color ='purple'> Alright.... I don't know about you, but I am no X-Ray reading wizard, but these don't look too off to me. </font>
#
# There are some obvious differences in the rib cage shape of the patient who has pneumonia vs someone who is normal. However, other than that I can't tell anything else.
#
# There are two ways, we can resolve this problem:
#
# 1. Go to Med-school and learn the skills that are necessary to read these figures and make educated guesses as to what they mean.
#
# 2. Not go $250,000 in debt and train a Convolutional Nerual Network to tell me the differnces...
#
# # Soooo.....
# ![https://media.giphy.com/media/l396ZJAsqbN5VX3O0/giphy.gif](http://media.giphy.com/media/l396ZJAsqbN5VX3O0/giphy.gif)

# %% [markdown]
# # <font color='red'> Have you ever wondered HOW and WHAT a computer sees?</font>
#
# The answer to that lies in mammilian physiology. The way we mammals and almost any other animal with two eyes and a developed brain sees is something as follows:
# 1. Rays of lights reflected off an object hit your retina.
# 2. The sensory input is transported to your brain.
# 3. The brain, after interpreting the input, tells you what it sees.
#
# Also, recall that your family was there to teach you what things are. You know something is an umbrella because you look at it and someone told you that this specific object is called an umbrella. Your brain, then stores that association and you don't have to be taught this again.
#
# **Computers,** learn/see in not such a different way from us. They will, however, need to look and analyze thousands upon thousands of images before they can generalize and say that a yellow umbrella falls under the same category as a black umbrella. This is because what they see are not pictures, but numerical representaions of pixels describing these pictures. So while we see **'things** in pictures, a computer sees this
# ![](https://cdn-images-1.medium.com/max/1600/1*cot55wd6gdoJlovlCw0AAQ.png)
#
#
# ![https://media.giphy.com/media/ChzfTLSi47FYc/giphy.gif](https://media.giphy.com/media/ChzfTLSi47FYc/giphy.gif)

# %% [markdown]
# # <font color='purple'>CONVOLUTIONAL NEURAL NETWORKS TO THE RESCUE</font>
# A Convolutional Neural Network is a special type of an Artificial Intelligence implementation which uses a  special mathematical matrix manipulation called the convolution operation to process data from the images.
#
# * A **convolution** does this by multiplying two matrices and yielding a third, smaller matrix.
# * The Network takes an input image, and uses a filter **(or kernel)**  to create a **feature map** describing the image.
# * In the convolution operation, we take a filter (usually 2x2 or 3x3 matrix ) and **slide** it over the image matrix. The coresponding numbers in both matrices are multiplied and and added to yield a single number describing that input space. This process is repeated all over the image.This can be seen in the following animation
# ![https://cdn-images-1.medium.com/max/800/1*VVvdh-BUKFh2pwDD0kPeRA@2x.gif](https://cdn-images-1.medium.com/max/800/1*VVvdh-BUKFh2pwDD0kPeRA@2x.gif)
#
# -------> This is a 2-D representation of calculations happening in 3 dimensions. This is what is actually happening
# ![Source: https://cdn-images-1.medium.com/max/800/1*EuSjHyyDRPAQUdKCKLTgIQ.png](https://cdn-images-1.medium.com/max/800/1*EuSjHyyDRPAQUdKCKLTgIQ.png)
#
# * We use different filters to pass over our inputs, and take all the feature maps, put them together as the final output of the convolutional layer.
# * We then pass the output of this layer through a non-linear activation function. The most commonly used one is ReLU.
# * The next step of our process involves further reducing the dimensionality of the data which will lower the computation power required for training this model. This is      achieved by using a **Pooling Layer.** The most commonly used one is **max pooling** which takes the maximum value in the window created by a filter. This              significantly reduces the training time and preserves significant information.
# ![https://cdn-images-1.medium.com/max/800/1*vbfPq-HvBCkAcZhiSTZybg.png](https://cdn-images-1.medium.com/max/800/1*vbfPq-HvBCkAcZhiSTZybg.png)
#
# Two of the most commonly associated words with CNN are **stride** and **padding **
#
# **STRIDE:** Stride just means the amount a filter moves during a covolution operation. So, a stride of 1 means that the filter will slide 1 pixel after each covolution operation as shown in this animation.
# ![https://cdn-images-1.medium.com/max/800/0*iqNdZWyNeCr5tCkc.](https://cdn-images-1.medium.com/max/800/0*iqNdZWyNeCr5tCkc.)
#
# **PADDING:** Padding is just zero value pixels that surround the input image. This protects the loss of any valuable information since the feature map is ever shrinking.
#
# *This section was inspired by this post: https://medium.freecodecamp.org/an-intuitive-guide-to-convolutional-neural-networks-260c2de0a050*
#
# *The gifs/animations are from this post: https://towardsdatascience.com/applied-deep-learning-part-4-convolutional-neural-networks-584bc134c1e2*

# %% [markdown]
# # <font color='purple'> There you go....all caught up. No need to be scared. If this looks intimidating don't worry, it is pretty easy to implement. </font>
#
# ![https://media.giphy.com/media/l3q2UyW34cT2rcgko/giphy.gif](https://media.giphy.com/media/l3q2UyW34cT2rcgko/giphy.gif)

# %% [markdown]
# # <font color ='purple'>Convolutional Neural Networks are easy to build and run because of the deep learning libraries such as Keras</font>
# * **Keras** is a high level deep learning library.
# * It runs on top of more low level libraries such as Tensorflow which is why you will usually see that message. 'Using TensorFlow backend.' display when you call Keras.
# * I am going to build a CNN that has 2 Convolution layers. After each convolution, I will add a Pooling layer using max-pooling.
# * After the second convolutional layer, we will add 2 Fully Connected layers which will take out feature map of an image and make predictions about it. The second FC
#    has only 1 unit becuase it needs to predict if someone has pneumonia.
#  * When we compile this CNN, we will use the Adam optimization fuction which optimizes how fast our model learns the correct classification of the image.                         Optimization functions are far too complex for me to get into in this post.

# %%
# let's build the CNN model

cnn = Sequential()

#Convolution
cnn.add(Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 3)))

#Pooling
cnn.add(MaxPooling2D(pool_size = (2, 2)))

# 2nd Convolution
cnn.add(Conv2D(32, (3, 3), activation="relu"))

# 2nd Pooling layer
cnn.add(MaxPooling2D(pool_size = (2, 2)))

# Flatten the layer
cnn.add(Flatten())

# Fully Connected Layers
cnn.add(Dense(activation = 'relu', units = 128))
cnn.add(Dense(activation = 'sigmoid', units = 1))

# Compile the Neural network
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# /home/arthur/Desktop/AI300/House_Rent_proj/CNN_Prediction_env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1777662640.279597  253710 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# I0000 00:00:1777662640.279627  253710 cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# I0000 00:00:1777662640.279630  253710 cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: arthur-Predator-PH315-53
# I0000 00:00:1777662640.279633  253710 cuda_diagnostics.cc:183] hostname: arthur-Predator-PH315-53
# I0000 00:00:1777662640.279758  253710 cuda_diagnostics.cc:190] libcuda reported version is: 535.288.1
# I0000 00:00:1777662640.279774  253710 cuda_diagnostics.cc:194] kernel reported version is: 535.288.1
# I0000 00:00:1777662640.279777  253710 cuda_diagnostics.cc:284] kernel version seems to match DSO: 535.288.1

# %% [markdown]
# # <font color='purple'>Now, we are going to fit the model to our training dataset and we will keep out testing dataset seperate </font>

# %%
num_of_test_samples = 600
batch_size = 32

# %%
# Fitting the CNN to the images
# The function ImageDataGenerator augments your image by iterating through image as your CNN is getting ready to process that image

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)  #Image normalization.

training_set = train_datagen.flow_from_directory('input/chest_xray/chest_xray/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

validation_generator = test_datagen.flow_from_directory('input/chest_xray/chest_xray/val/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary')

test_set = test_datagen.flow_from_directory('input/chest_xray/chest_xray/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# # This summary is a great way for us to see how our CNN is being set up

# %%
cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       802,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 813,217 (3.10 MB)
#  Trainable params: 813,217 (3.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#ploting cnn model:

# %%
cnn_model = cnn.fit_generator(training_set,
                         steps_per_epoch = 163,
                         epochs = 1,
                         validation_data = validation_generator,
                         validation_steps = 624)
# Out:
# Epoch 1/1
# 163/163 [==============================] - 194s 1s/step - loss: 0.2425 - acc: 0.9011 - val_loss: 0.2809 - val_acc: 0.8750

# %%
test_accu = cnn.evaluate_generator(test_set,steps=624)

# %%
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# The testing accuracy is : 88.96364009860312 %

# %% [markdown]
# # <font color='green'>PHEW!!! So we just built a CNN that can predict penumonia from X-Ray scans !!! WOOOOO</font>
#
#
# ![https://media.giphy.com/media/3ov9jG4eqz9k3XXsU8/giphy.gif](https://media.giphy.com/media/3ov9jG4eqz9k3XXsU8/giphy.gif)

# %% [markdown]
# # <font color='purple'> Let's take a look at the Confusion matrix and the Classification Report. </font>

# %%
Y_pred = cnn.predict_generator(test_set, 100)
y_pred = np.argmax(Y_pred, axis=1)
# confusion_matrix(validation_generator.classes, y_pred)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
max(y_pred)
# Out:
# 0

# %% [markdown]
# # <font color='purple'>Now, let's see how accuracy changed over our training and Validation Set and also how our Loss function changed!!</font>

# %%
# Accuracy 
plt.plot(cnn_model.history['acc'])
plt.plot(cnn_model.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
# Loss 

plt.plot(cnn_model.history['val_loss'])
plt.plot(cnn_model.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Test set'], loc='upper left')
plt.show()

# %% [markdown]
# ### Saving the model:

# %%
cnn.save("pneumonia-cnn-model.h5")

# %% [markdown]
# # <font color='red'> What this means? </font>
# The world of medical imaging is ripe for a revolution in terms of deploying CNN based technologies. There is no need for a doctor or a health care provider to ponder these images to gauge things. This is not a shot at doctors or their jobs! The task of reading these is incredibly menial and repititive. Those are two things that AI technologies are great at. I will be working with some more bio-medical imaging dataset just to get more practice and probably create some web applications online for atleast one of them!!
